# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/Users/anusha/Downloads/diamonds.csv')

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
plt.subplots(figsize = (10,10))
sns.heatmap(df.corr(), annot = True, cmap = "Blues")

# %%
df["carat"].hist(bins = 70)

# %%
df["cut"].value_counts().plot.barh().set_title("Cut")
# Out:
# Text(0.5, 1.0, 'Cut')

# %%
sns.barplot(x=df.cut,y=df.cut.index);

# %%
df.groupby(["cut","color"])["price"].mean()
# Out:
# cut        color
# Fair       D        4291.061350
#            E        3682.312500
#            F        3827.003205
#            G        4239.254777
#            H        5135.683168
#            I        4685.445714
#            J        4975.655462
# Good       D        3405.382175
#            E        3423.644159
#            F        3495.750275
#            G        4123.482204
#            H        4276.254986
#            I        5078.532567
#            J        4574.172638
# Ideal      D        2629.094566
#            E        2597.550090
#            F        3374.939362
#            G        3720.706388
#            H        3889.334831
#            I        4451.970377
#            J        4918.186384
# Premium    D        3631.292576
#            E        3538.914420
#            F        4324.890176
#            G        4500.742134
#            H        5216.706780
#            I        5946.180672
#            J        6294.591584
# ...

# %%
sns.distplot(df.carat)

# %%
sns.distplot(df["price"],kde=False,bins=10,color="red");

# %%
sns.distplot(df.price,hist=False,color="purple");

# %%
sns.kdeplot(df.price,shade=True);

# %%
sns.FacetGrid(df, hue="cut", height=5, xlim=(0,10000)).map(sns.kdeplot,"price",shade=True).add_legend()

# %%
sns.boxplot(df["price"])

# %%
sns.distplot(df.depth)

# %%
sns.distplot(df.table,bins=20)

# %%
sns.distplot(df.x)

# %%
sns.distplot(df.y)

# %%
sns.distplot(df.z)

# %%
sns.boxplot(df['carat'])

# %%
sns.boxplot(df['depth'])
